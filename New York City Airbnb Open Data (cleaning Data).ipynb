# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"D:\Oasis Infobyte Intership\Cleaning Data\AB_NYC_2019.csv")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
numerical = ['id','host_id','price','minimum_nights','number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']

corr = df[numerical].corr()

# %%
corr
# Out:
#                                       id   host_id     price  minimum_nights  \
# id                              1.000000  0.588290  0.010619       -0.013224
# host_id                         0.588290  1.000000  0.015309       -0.017364
# price                           0.010619  0.015309  1.000000        0.042799
# minimum_nights                 -0.013224 -0.017364  0.042799        1.000000
# number_of_reviews              -0.319760 -0.140106 -0.047954       -0.080116
# reviews_per_month               0.291828  0.296417 -0.030608       -0.121702
# calculated_host_listings_count  0.133272  0.154950  0.057472        0.127960
# availability_365                0.085468  0.203492  0.081829        0.144303
#
#                                 number_of_reviews  reviews_per_month  \
# id                                      -0.319760           0.291828
# host_id                                 -0.140106           0.296417
# ...

# %% [markdown]
# so studying the graph above we can see that the highest positive relationship is between the number of reviews and the reviews per month which surprise surprise! makes sense. i honestly thought it should be higher than that but we have null values so.
#
# So i think it's safe to say now that there is no correlation whatsoever among this data so let's move on

# %%
summary_stats_col = ['price', 'minimum_nights', 'number_of_reviews','reviews_per_month','calculated_host_listings_count','availability_365']
summary_stats = df[summary_stats_col].describe()

summary_stats
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  48895.000000    48895.000000       48895.000000       38843.000000
# mean     152.720687        7.029962          23.274466           1.373221
# std      240.154170       20.510550          44.550582           1.680442
# min        0.000000        1.000000           0.000000           0.010000
# 25%       69.000000        1.000000           1.000000           0.190000
# 50%      106.000000        3.000000           5.000000           0.720000
# 75%      175.000000        5.000000          24.000000           2.020000
# max    10000.000000     1250.000000         629.000000          58.500000
#
#        calculated_host_listings_count  availability_365
# count                    48895.000000      48895.000000
# mean                         7.143982        112.781327
# std                         32.952519        131.622289
# min                          1.000000          0.000000
# ...

# %% [markdown]
# so what does this table tell us?
#
# starting with the standard deviation we can see that price and availability have very high variation among their numbers which means that some hosts have very high prices and some have very low and the same goes for availability, so this i think is worth investigating to see if host with high prices have small rate of occupancy or not.
#
# the reviews per month std shows that most listings are in the same range. while other variations have moderate variations.
#
# so the next think i want to do is to check for skewness and draft a graph to see if we have any outliers so let's start with skewness and narrow it down from there.

# %%
from scipy.stats import skew

skewness = df[summary_stats_col].skew()
print(skewness)
# Out:
# price                             19.118939
# minimum_nights                    21.827275
# number_of_reviews                  3.690635
# reviews_per_month                  3.130189
# calculated_host_listings_count     7.933174
# availability_365                   0.763408
# dtype: float64

# %% [markdown]
# so we can see that both price and minimum nights show the highest positive skewness among the other features. so let's see a graph for those.

# %%
df[summary_stats_col] = df[summary_stats_col].replace(0, np.nan)
df[summary_stats_col] = df[summary_stats_col].replace([np.inf, -np.inf], np.nan)

skew_df = df[summary_stats_col]b

plt.figure(figsize=(10,8))

for i, col in enumerate(skew_df.columns):
    plt.subplot(3,3,i+1)
    sns.histplot(skew_df[col],kde=True,bins=10,color='purple',stat='density')
    sns.scatterplot(x=skew_df[col], y=[0]*len(skew_df[col]), marker='o', color='red', s=50, label='Outliers')
    plt.title(f'Outliers in {col}')
    plt.xlabel(col)
    plt.ylabel("Density")
    plt.legend()
    
plt.tight_layout()
plt.show()

# %% [markdown]
# since all features except availability are way too positively skewed we can assume that the median is our real middle or typical value.
#
# so now to answer the second question i want to check the performance of the hosts above the median and below the median and see their performance.
#
# but to see the threshold i need to find the total number of reviewes per host and then check the median for that

# %%
filtered_df = df[df['number_of_reviews'] != 0]

reviews_sum = filtered_df.groupby('host_name')['number_of_reviews'].sum().reset_index()

# Calculate median of the sums
median_reviews = reviews_sum['number_of_reviews'].median()

print("Median number of reviews (excluding zeros) by host:")
print(median_reviews)
print(reviews_sum['number_of_reviews'].skew())
sns.displot(reviews_sum['number_of_reviews'], kde=True, bins=100)
# Out:
# Median number of reviews (excluding zeros) by host:
# 14.0
# 11.646602315183307

# %%
reviews_sum.head(200)
# Out:
#                     host_name  number_of_reviews
# 0                        'Cil              240.0
# 1             (Ari) HENRY LEE                3.0
# 2    (Email hidden by Airbnb)               75.0
# 3                 (Mary) Haiy              188.0
# 4         -TheQueensCornerLot               51.0
# ..                        ...                ...
# 195                     Ailee                1.0
# 196                    Aileen                9.0
# 197                     Ailin                1.0
# 198                     Aimar                7.0
# 199                     Aimee              188.0
#
# [200 rows x 2 columns]

# %% [markdown]
# okay so what i'm thinking is i want to measure the performance of hosts by their prices, occupancy rate and number of reviews they get and see if their is a noticable pattern among the best performing host or not.
#
# so i'm thinking of creating two tables in power BI one that shows the top ten performing hosts and another that shows the lowest performing hosts and then combine them in one before visualising them.
#
# the problem is that many hosts share the sam minimum values so i thought i can use the median oe the 75th percentile as my threshold but let's check something first.

# %%
review_counts = reviews_sum.groupby('number_of_reviews')['host_name'].nunique().reset_index()

review_counts.columns = ['number_of_reviews', 'unique_hosts_count']
print(review_counts)
# Out:
#      number_of_reviews  unique_hosts_count
# 0                  0.0                1566
# 1                  1.0                 847
# 2                  2.0                 582
# 3                  3.0                 449
# 4                  4.0                 371
# ..                 ...                 ...
# 813             6204.0                   1
# 814             6522.0                   1
# 815             7223.0                   1
# 816             8103.0                   1
# 817            11081.0                   1
#
# [818 rows x 2 columns]

# %% [markdown]
# here you can see what i mean by sharing the same number of reviews
#
# one approach would be to use the price column as a way to choose my best and worst performing hosts since it has higher variation among it's values. so let's see it.

# %%
price_count = df.groupby('price')['host_name'].nunique().reset_index()

price_count.columns = ['price','unique_host_count']
print(price_count)
# Out:
#        price  unique_host_count
# 0       10.0                 16
# 1       11.0                  3
# 2       12.0                  4
# 3       13.0                  1
# 4       15.0                  6
# ..       ...                ...
# 668   7703.0                  1
# 669   8000.0                  1
# 670   8500.0                  1
# 671   9999.0                  3
# 672  10000.0                  3
#
# [673 rows x 2 columns]

# %%
df_price_filtered = df[df['price'] == 106.0]

unique_hosts_count = df_price_filtered.groupby('price')['host_name'].nunique().reset_index()
print(f'Hosts sharing the 75th percentile value = {unique_hosts_count}')
# Out:
# Hosts sharing the 75th percentile value =    price  host_name
# 0  106.0         35

# %%
room_type_count = df['room_type'].value_counts()
print(room_type_count)
# Out:
# room_type
# Entire home/apt    25409
# Private room       22326
# Shared room         1160
# Name: count, dtype: int64

# %%
df_reviews_filtered = df.dropna(subset=['last_review','reviews_per_month'])

print(f"Original number of rows: {len(df)}")
print(f"Number of rows after dropping nulls: {len(df_reviews_filtered)}")
# Out:
# Original number of rows: 48895
# Number of rows after dropping nulls: 38843

# %%
df_reviews_filtered['last_review'] = pd.to_datetime(df_reviews_filtered['last_review'], errors='coerce')

print(df_reviews_filtered['last_review'].isnull().sum())
# Out:
# 0

# %%
df_reviews_filtered['Year_month'] =df_reviews_filtered['last_review'].dt.to_period('M')

df_reviews_filtered.head(7)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 3  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan         East Harlem  40.79851  -73.94399
# ...

# %%
monthly_data = df_reviews_filtered.groupby('Year_month').agg(
    Monthly_Listings=('id', 'count'),
    Monthly_Reviews=('number_of_reviews', 'sum')
).reset_index()

print(monthly_data)
# Out:
#    Year_month  Monthly_Listings  Monthly_Reviews
# 0     2011-03                 1              1.0
# 1     2011-04                 1             14.0
# 2     2011-05                 1              2.0
# 3     2011-09                 2             10.0
# 4     2011-12                 2             34.0
# ..        ...               ...              ...
# 87    2019-03               820          11307.0
# 88    2019-04              1456          24828.0
# 89    2019-05              3697          86486.0
# 90    2019-06             12601         619907.0
# 91    2019-07              4725         243262.0
#
# [92 rows x 3 columns]

# %%
monthly_data['Listings_growth_rate'] = monthly_data['Monthly_Listings'].pct_change()
monthly_data['Reviews_growth_rate'] = monthly_data['Monthly_Reviews'].pct_change()

monthly_data.loc[0, 'Listings_Growth_Rate'] = None
monthly_data.loc[0, 'Reviews_Growth_Rate'] = None

print(monthly_data[['Year_month', 'Listings_growth_rate', 'Reviews_growth_rate']])
# Out:
#    Year_month  Listings_growth_rate  Reviews_growth_rate
# 0     2011-03                   NaN                  NaN
# 1     2011-04              0.000000            13.000000
# 2     2011-05              0.000000            -0.857143
# 3     2011-09              1.000000             4.000000
# 4     2011-12              0.000000             2.400000
# ..        ...                   ...                  ...
# 87    2019-03              0.744681             0.567152
# 88    2019-04              0.775610             1.195808
# 89    2019-05              1.539148             2.483406
# 90    2019-06              2.408439             6.167715
# 91    2019-07             -0.625030            -0.607583
#
# [92 rows x 3 columns]

# %%
df_reviews_filtered = pd.merge(df_reviews_filtered, monthly_data, on='Year_month', how='left')

df_reviews_filtered.head(7)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3831                   Cozy Entire Floor of Brownstone     4869
# 3  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 4  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 5  5121                                   BlissArtsSpace!     7356
# 6  5178                  Large Furnished Room Near B'way      8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 3        Laura           Manhattan         East Harlem  40.79851  -73.94399
# ...

# %%
df_reviews_filtered = df_reviews_filtered.drop(columns=['Listings_Growth_Rate', 'Reviews_Growth_Rate'])

df_reviews_filtered.head(7)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3831                   Cozy Entire Floor of Brownstone     4869
# 3  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 4  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 5  5121                                   BlissArtsSpace!     7356
# 6  5178                  Large Furnished Room Near B'way      8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan             Midtown  40.75362  -73.98377
# 2  LisaRoxanne            Brooklyn        Clinton Hill  40.68514  -73.95976
# 3        Laura           Manhattan         East Harlem  40.79851  -73.94399
# ...

# %%
df_reviews_filtered['Year_month'] = pd.to_datetime(df_reviews_filtered['Year_month'].astype(str))

# %%
plt.figure(figsize=(10, 6))
for group, data in df_reviews_filtered.groupby('neighbourhood_group'):
    plt.plot(data['Year_month'], data['Listings_growth_rate'], label=group)

plt.title('Listings Growth Rate by Neighbourhood Group')
plt.xlabel('Year-Month')
plt.ylabel('Listings Growth Rate')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Finish
